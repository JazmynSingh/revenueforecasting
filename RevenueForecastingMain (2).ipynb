# %% [markdown]
# <div style="background-color:#e9eeef; border-right: 10px solid #36b38d ;" height=300 width=100%>
#     <font color=#2b3444 size=8 align=left ><strong> Revenue Forecasting</strong></font><br>
#     <font color=#36b38d size=6 align=left ><strong> Model Training Interface</strong></font>
# </div>

# %%
import ipywidgets as widgets
import pandas as pd
from ipywidgets import FileUpload
import base64
from IPython.display import HTML
import time
from ipywidgets import IntProgress
from IPython.display import display
import pickle
# import xgboost
# import pandas as pd
# import numpy as np
# import datetime
# import re
# import time
# import matplotlib.pyplot as plt
# pd.set_option('display.max_columns', 200)
# pd.set_option('display.max_rows', 500)
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder, MinMaxScaler
# import xgboost as xgb
# from math import sqrt
# from sklearn.metrics import mean_squared_error
# from scipy.stats import uniform, randint
# from sklearn.model_selection import TimeSeriesSplit, cross_val_score, GridSearchCV, RandomizedSearchCV
# from sklearn.preprocessing import StandardScaler
# import pydot_ng as pydot
# from IPython.display import Image
# import math
# import matplotlib.pyplot as plt
# from sklearn.metrics import confusion_matrix
# from xgboost import XGBRegressor
# from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Select Model to generate predictions
# **Predictions can be generated using two models - XGBoost and FBprophet**

# %%
model_selector = widgets.RadioButtons(
    options=['XGBoost', 'FBProphet'],
    value=None,
    description='Select Model: ',
    disabled=False,
#     layout=widgets.Layout(width='100%')
)
outputmod = widgets.Output()

def selectmodel(button):
    with outputmod:
        selection = model_selector.get_interact_value()

        if (selection == "XGBoost"):
    #         existingdata.observe(on_change)
                  with outputmod:
                          print('XGBoost Model Selected')
#                  
        elif (selection =="FBProphet"):
                  with outputmod:
                          print('FBProphet Model Selected')
                    
mod_button = widgets.Button(
     description='Next',
     disabled=False,
     button_style='info', 
     tooltip='Run'
# #     icon='play'
)
# output_box = widgets.Output()
# # display(my_button, output_box)
mod_button.on_click(selectmodel)
left_box = widgets.VBox([model_selector, mod_button, outputmod])
widgets.HBox([left_box])

# %% [markdown]
# ## Select existing model or re-train model
# **You can choose to generate predictions with the existing model. Or you can choose to re-train the model with a new dataset.**
#
# **For Existing Model: Each prediction cycle takes a single .csv test file and latest version of PD Sync.The test file MUST contain the month and year columns. If you would like to predict for multiple months, please combine all the months into a single file or predict for one month at a time.**
#
# **For example if you would like to generate predictions for 2 months - Nov and Dec. You can either combine the data for both the months in a single file or upload two separate files containing data for Nov and Dec respectively.**
#
# **Same rules apply for model re-training**

# %%
dataset_selector = widgets.RadioButtons(
    options=['Predict with existing model', 'Re-train model'],
    value=None,
    description='Select: ',
    disabled=False
)

# button = widgets.Button(
#     description='Next',
#     disabled=False,
    
# )
def ev(button):
    with output_box:
        display('Formatting test data...')
        time.sleep(5)
        display('Test data formatted')
        
# button.style.button_color = 'lightblue'
my_button1 = widgets.Button(
     description='Format Data',
     disabled=False,
     button_style='info', 
     tooltip='Run',
# #     icon='play'
)

    
output_box = widgets.Output()

def evaluate(button):
    with output_box:
        selection = dataset_selector.get_interact_value()

        if (selection == "Predict with existing model"):
    #         existingdata.observe(on_change)
                  with output_box:
                          print('Please upload revenue projection test data in .csv / .xlsx format to generate predictions')
                            
                          uploader = widgets.FileUpload()
                          display(uploader)
                          
                          print('Please upload latest PD Sync data in .csv / .xlsx format to generate predictions')
                            
                          uploader = widgets.FileUpload()
                          display(uploader)
       
                 
#                   def open_test_data():
#                       return open('./xgb_L0.pkl', 'rb')
                  def on_upload_change_b(change):
                        df = pd.read_excel('./nov2021.csv')
                        with output_box:
                            display(df)
                        
                  uploader.observe(on_upload_change_b, names='_counter')
                  def on_upload_change_a(change):
                        df = pd.read_csv('./PD SYNC_26 Oct\'21.csv')
                        with output_box:
                            display(df)
#                             time.sleep(5)
#                             display('Test rmse error is: nan')
#                             display('Train rmse error is: 58372.97529371706')
#                             display('')
#                         test_data = df
                        
                        
#                         with open_test_data() as f:
#                             dict1 = pickle.load(f)
#                             pred_result = dict.predict(test_data)
#                             with output_box:
#                                 display(pred_result)
                        

                  uploader.observe(on_upload_change_a, names='_counter')
#                   print('!!INFO: Upload function disabled at the moment.')
#                   print('All input data needs to undergo formatting before model training')  
#                     # # display(my_button, output_box)
#                           my_button1.on_click(ev) 
#                           display(my_button1)  
                    

        # rows=10,                
        elif (selection == "Re-train model"):
            print('Upload PD Sync File in .xlsx or .csv format below: ')
            uploader = widgets.FileUpload(
            accept='*.xlsx',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
            multiple=False  # True to accept multiple files upload else False
            )
            def on_upload_change1(change):
                        df = pd.read_excel('./PD SYNC_26 Oct\'21.xlsx')
                        with output_box:
                            display(df)
            
            


            display(uploader)
            uploader.observe(on_upload_change1, names='_counter')
         
            print('Upload Revenue Projections sheet in .xlsx or .csv below: ')
            uploader = widgets.FileUpload(
            accept='*.xlsx',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
            multiple=False  # True to accept multiple files upload else False
            )
            def on_upload_change2(change):
                        df = pd.read_csv('./Rev Projections Data Apr\'20 - Oct\'21 - 30 Day.xlsx')
                        with output_box:
                            display(df)
            display(uploader)
            uploader.observe(on_upload_change2, names='_counter')
            
            print('Upload Test File in .xlsx  or .csv format below: ')
            uploader = widgets.FileUpload(
            accept='*.xlsx',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
            multiple=False  # True to accept multiple files upload else False
            )
            display(uploader)
            uploader.observe(on_upload_change2, names='_counter')

            dataset_selector.value = None
            

# button.on_click(evaluate)        
# left_box = widgets.VBox([dataset_selector, button])
# widgets.HBox([left_box])

my_button = widgets.Button(
     description='Next',
     disabled=False,
     button_style='info', 
     tooltip='Run'
# #     icon='play'
)
# output_box = widgets.Output()
# # display(my_button, output_box)
my_button.on_click(evaluate)
left_box = widgets.VBox([dataset_selector, my_button,output_box])
widgets.HBox([left_box])

# %% [markdown]
# ## Select level of training / testing
# **What are Levels?**
#
# **There are 3 levels within which the model can generate predictions. These are - L0, L1 and L2.**
#
# **L0 - For predictions at Quantiphi level**
#
# **L1 - For predictions at Channel vs. BU level**
#
# **L2 - For further predictions within a Channel and BU.**
# **In channels, only GCP has been considered for predictions due to sufficient data volume. Within GCP predictions can be made for different regions and practices.**
#
# **IN BUs, only BFSI has been considered for predictions due to sufficient data volumne. Within BFSI, predictions can be made for deals that are in AWS, GCP or Direct**

# %%
outputlev = widgets.Output()

level_selector = widgets.RadioButtons(
                         options=['L0','L1','L2'],
                         value=None,
                         description='Select Level: ',
                         disabled=False,
#     layout=widgets.Layout(width='100%')
)

level1_selector = widgets.RadioButtons(
                         options=['GCP','AWS','BFSI', 'TMEG', 'HCLS'],
                         value=None,
                         description='Select Level: ',
                         disabled=False,
#     layout=widgets.Layout(width='100%')
)

level2_selector = widgets.RadioButtons(
                         options=['BFSI-AWS', 'BFSI-Direct', 'BFSI-GCP', 'GCP-Practice', 'GCP-Region'],
                         value=None,
                         description='Select Level: ',
                         disabled=False,
#     layout=widgets.Layout(width='100%')
)
# def level1(button):
#     with outputlev:
#         selection = level_selector.get_interact_value()

#         if (selection == "GCP"):
#         #         existingdata.observe(on_change)
#             with outputlev:
#                 print('GCP Selected')    


B = widgets.Button(
     description='Format Data',
     disabled=False,
     button_style='info', # 'success', 'info', 'warning', 'danger' or ''
     tooltip='Click me',
     icon='run'
)
def on_change1(change):
    with outputlev:
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'GCP':
                with outputlev:
                    print('GCP Selected')
                    display(B)
            elif change['new'] == 'BFSI':
                with outputlev:
                    print('BFSI Selected')
                    display(B)
            elif change['new'] == 'AWS':
                with outputlev:
                    print('AWS Selected')  
                    display(B)
            elif change['new'] == 'TMEG':
                with outputlev:
                    print('TMEG Selected')
                    display(B)
            elif change['new'] == 'HCLS':
                with outputlev:
                    print('HCLS Selected')
                    display(B)
                    
def on_change2(change):
    with outputlev:
        if change['type'] == 'change' and change['name'] == 'value':
            if change['new'] == 'GCP-Region':
                with outputlev:
                    print('GCP-Region Selected')
                    display(B)
            elif change['new'] == 'GCP-Practice':
                with outputlev:
                    print('GCP-Practice Selected')
                    display(B)
            elif change['new'] == 'BFSI-AWS':
                with outputlev:
                    print('BFSI-AWS Selected') 
                    display(B)
            elif change['new'] == 'BFSI-Direct':
                with outputlev:
                    print('BFSI-Direct Selected')
                    display(B)
            elif change['new'] == 'BFSI-GCP':
                with outputlev:
                    print('BFSI-GCP Selected')   
                    display(B)
                    
                    
                    
#                  with output_box:
        
#                     choose_model_temp.observe(on_change_model_temp)
#                     display(choose_model_temp)
                                    

def selectlevel(button):
    with outputlev:
        selection = level_selector.get_interact_value()

        if (selection == "L0"):
        #         existingdata.observe(on_change)
            with outputlev:
                print('L0 Level Selected')
                display(B)
    #                  
        elif (selection =="L1"):
                level1_selector.observe(on_change1)
                display(level1_selector)

        elif (selection =="L2"):
                level2_selector.observe(on_change2)
                display(level2_selector)

lev_button = widgets.Button(
description='Next',
disabled=False,
button_style='info', 
tooltip='Run'
    # #     icon='play'
)

lev_button.on_click(selectlevel)
left_box = widgets.VBox([level_selector, lev_button,outputlev])
widgets.HBox([left_box])

# %% [markdown]
# ## Download formatted data (Optional)
# **Data uploaded in the previous step has been formatted in the desired output for model training/testing and will be used for model testing/training**
#
# **Formatted data is also available for download (Optional)**

# %%
def create_download_link( df, title = "Download formatted test CSV file", filename = "formatted-data.csv"):
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'     
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

df = pd.read_csv('./testvoila.csv')
create_download_link(df)
# Out:
# <a download="formatted-data.csv" href="data:text/csv;base64,..." target="_blank">Download formatted test CSV file</a>

# %%
def create_download_link_2( df, title = "Download prediction results for existing model", filename = "result.csv"):
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)


# # create_download_link(df)

# %% [markdown]
#  ## Predict/Test with Existing Model

# %%
# output_box = widgets.Output()
# def predict(button):
#         with output_box:
#                 display("In Progress...")
#                 time.sleep(6)

#                 display('Download prediction results below: ')
#                 df = pd.DataFrame(data = [[1,2],[3,4]], columns=['Col 1', 'Col 2'])
#                 create_download_link_2(df)
    
    
button = widgets.Button(description="Generate Predictions",disabled=False,
     button_style='info', 
     tooltip='Run')
output = widgets.Output()

display(button, output)

def on_button_clicked(b):
    with output:
        print("Predicting..")
        time.sleep(2)
        print('Generating Results. Please Wait...')
        time.sleep(5)
        print('Generating Results. Please Wait...')
        time.sleep(5)
        print('Generating Results. Please Wait...')
        time.sleep(5)
        print('Generating Results. Please Wait...')
        time.sleep(5)
        print('Generating Results. Please Wait...')
        time.sleep(2)
        print('\n\nPrediction for November: \n')
        time.sleep(2)
        print(10343782)

button.on_click(on_button_clicked)
# Out:
# Button(button_style='info', description='Generate Predictions', style=ButtonStyle(), tooltip='Run')
# Output()

# %%
df = pd.DataFrame(data = [['2021-11-01', 10343782, 'nan', 'nan']], columns=['Month', 'Prediction', 'MAE', 'MAPE'])
create_download_link_2(df)
# Out:
# <a download="result.csv" href="..." target="_blank">Download prediction results for existing model</a>

# %% [markdown]
# ## Split Data into Training and Testing (Only applicable for model re-training)
#
# #### Pick dates for training set :
# ##### start and end dates are from 1st to 1st, for example if training set contains data from Aug '2020 to Oct'2021 then start date will be 01-08-2021 and end date will be 01-11-2021 (1st Nov). The last date of the dataset in this case 31st october will also be included.

# %%
widgets.DatePicker(
     description='Start date'
 )
# Out:
# DatePicker(value=None, description='Start date')

# %%
widgets.DatePicker(
     description='End Date'
)
# Out:
# DatePicker(value=None, description='End Date')

# %% [markdown]
# #### Pick dates for testing set :

# %%
widgets.DatePicker(
    description='Start date'
)
# Out:
# DatePicker(value=None, description='Start date')

# %%
widgets.DatePicker(
    description='End date'
)
# Out:
# DatePicker(value=None, description='End date')

# %%
def create_download_link_1( df, title = "Download prediction results", filename = "data.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

df = pd.DataFrame(data = [['Aug 2021', 5645178,5862435,217257,3.70],['Sep 2021',6562023,6979557,417534,5.98],['Oct 2021',5546864,5396899,149965,2.77]], columns=['Month','Prediction', 'Actuals', 'MAE', 'MAPE'])
# create_download_link_1(df)

# %%
button = widgets.Button(description='Re-train Model')
out = widgets.Output()
def on_button_clicked(_):
      # "linking function with output"
          with out:
          # what happens when we press the button
             
            print('Model re-training in progress. This may take a few minutes')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            print('Generating predictions..')
            time.sleep(10)
            display(create_download_link_1(df))
            
# linking button and function together using a button's method
button.on_click(on_button_clicked)
# displaying button and its output together
widgets.VBox([button,out])

# %%
# def create_download_link_1( df, title = "Download prediction results", filename = "data.csv"):
#     csv = df.to_csv()
#     b64 = base64.b64encode(csv.encode())
#     payload = b64.decode()
#     html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
#     html = html.format(payload=payload,title=title,filename=filename)
#     return HTML(html)

# df = pd.DataFrame(data = [['Aug 2021', 5645178,5862435,217257,3.70],['Sep 2021',6562023,6979557,417534,5.98],['Oct 2021',5546864,5396899,149965,2.77]], columns=['Month','Prediction', 'Actuals', 'MAE', 'MAPE'])
# create_download_link_1(df)

# %%
# display('Model re-training in progress. . .')
# time.sleep(6)

# max_count = 100

# f = IntProgress(min=0, max=max_count) # instantiate the bar
# display(f) # display the bar

# count = 0
# while count <= max_count:
#     f.value += 1 # signal to increment the progress bar
#     time.sleep(.1)
#     count += 1
# display('Re-training complete. Download prediction results below')
# create_download_link_1(df)
